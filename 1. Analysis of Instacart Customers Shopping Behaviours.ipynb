# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# Thank you for the updates! My new comments have digit 3.  However, there are no issues that need to be fixed.
#
#
#
#
# Your project has passed code review. Congratulations 🎉
#
#
#
# This is a good [article](https://www.kaggle.com/ramprakasism/pandas-75-exercises-with-solutions/notebook) with 75 pandas exercises and solutions. You can go along the exercises and compare your solution with the solution in the article.
#
#
#
# Good luck! 😊
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for sending a new version of the project 😊 I've left a few comments titled as **Reviewer's comment 2**. Please take a look :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, I am a reviewer on this project. Glad to see you here!
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> you did a good job, everything is clear and neat. The project is easy to read, which is definitely a plus. There are a lot graphs. It is good, visualization never hurts. I still have some questions that I've written in my comments. For instance,
#
#
#
# - Please do not forget to add a conclusion to each task in sections A, B, and C.
#
#
# - Don't forget about the overall conclusion as well: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
#
#
# I've also left there some recommendations for improving the project.  I will wait for the project for the second review :)
#
#
# <hr>
#
# Please feel free to schedule a 1:1 with our tutors or TAs, join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance.
#
#
# <hr>
# 📌 Here are some hints that may help you with Markdown cells:
# <hr style="border-top: 3px solid purple; "></hr>
#
# You can leave comments using this code inside a Markdown cell:
#
#
#     <div class="alert alert-info">
#     <h2> Student's comment</h2>
#
#     Your text here.
#     </div>
#
#
#
#     <font color='red'> This code is used to change text color. </font>
#
# <font color='red'> It will look like this. </font>
#
# If you don't want your comments to be headings, replace **h2** with **b** or just add `<a class="tocSkip">` after the phrase *Student's comment*.
#
#
# You can find out how to **format text** in a Markdown cell or how to **add links** [here](https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet).
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project.
#
#
# Please add a title and project description.
#
# </div>

# %% [markdown]
# ## Instacart Customer Order Analysis
# Our objective is to review the datasets to identify trends within customer behavior.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Great! :) It's a good habit actually. I have about 200 notebooks on my laptop with different tasks. Without a good intro it would be hard to remember what a particular notebook is about.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment 2 ⚠️</h2>
#
# However, try to make it broader next time :)
# </div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
orders_df = pd.read_csv('/datasets/instacart_orders.csv', sep=";")
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
# Try to use **display** instead of **print** for the dataframes :)
#
#
# Display is a great thing. However, jupyter notebook is an interactive environment that already includes display. When we call a dataframe (see the code below), jupyter prints this dataframe like we do with the display method:
#
# </div>

# %%
# Reviewer's code

display(orders_df.head(3))

orders_df.tail(3)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 478964                     6.0
# 478965                     8.0
# 478966                    15.0

# %%
products_df = pd.read_csv('/datasets/products.csv', sep=";")
display(products_df)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
order_products_df = pd.read_csv('/datasets/order_products.csv', sep =";" )
display(order_products_df)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %%
aisles_df = pd.read_csv('/datasets/aisles.csv', sep= ";")
display(aisles_df)
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
departments_df = pd.read_csv('/datasets/departments.csv', sep=";")
display(departments_df)
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# Importing all the datasets

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment ✔️</h2>
#
# The data was successfully read, good.
#
# </div>

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders

orders_df.duplicated().sum()
# Out:
# 15

# %%
# Check for all orders placed Wednesday at 2:00 AM
display(orders_df[(orders_df['order_dow'] == 3) & (orders_df['order_hour_of_day'] == 2)])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# Output shows there are 121 orders placed on Wed @ 2am. 'order_dow' has a min value of 0 and max of 6. Given lack of documentation, we can only assume Sunday = 'order_dow' 0 & Wed = 'order_dow' 3

# %%
# Remove duplicate orders
orders_df=orders_df.drop_duplicates()

# %%
# Double check for duplicate rows
display(orders_df.duplicated().sum())
# Out:
# 0

# %%
# Double check for duplicate order IDs only
duplicate_count = orders_df['order_id'].duplicated().sum()
display(duplicate_count)
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# There are no duplicates here, good.
# </div>

# %% [markdown]
# ### `products` data frame

# %% [markdown]
# #### Check and remove the missing values

# %%
products_df.isna().sum()
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# #### Check and tackle the duplicated values

# %%
# Check for fully duplicate rows
display(products_df.duplicated().sum())
# Out:
# 0

# %%
# Check for just duplicate product IDs
duplicate_count = products_df['product_id'].duplicated().sum()
display(duplicate_count)
# Out:
# 0

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)

products_df['product_name'].str.lower().duplicated().sum()

#products_df['product_name'].str.lower().isna() 
#duplicated_products = products_df[products_df.duplicated(subset=['product_name'], keep=False)]
#print(duplicated_products)

#.value_counts()
# Out:
# 1361

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Correct.
#
# </div>

# %%
# Check for duplicate product names that aren't missing
print(products_df['product_name'].dropna().str.lower().duplicated().sum())
products_df[products_df['product_name'].str.lower().duplicated(keep=False)].sort_values('product_name').head(10)


#print(products_df['product_name'].dropna().str.lower().duplicates())
#print(products_df['product_name'].dropna().str.lower().duplicated())
#products_df = products_df['product_name'].dropna()
# Out:
# 104
#        product_id                               product_name  aisle_id  \
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 22582       22583         Albacore Solid White Tuna In Water        95
# 24830       24831         Albacore Solid White Tuna in Water        95
# 515           516                     American Cheese Slices        21
# 9037         9038                     American Cheese slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id
# 31844             11
# 23339             11
# 19941             13
# 13152             13
# 22582             15
# 24830             15
# 515               16
# ...

# %% [markdown]
# These duplicates appear to be caused by a duplication of product_id. All the items have their respective department and asile id's noted correctly, but have conflicting product_id's

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Do not forget about the conclusion please. What can you say about these duplicates?
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 3 ✔️</h2>
#
#
# Yes, they may have different `product_id`, so I am not sure whether we should treat them as duplicates. It's a good habit to always analyze the result :)
#
#
# </div>

# %%
print(products_df['product_name'])
# Out:
# 0                               Chocolate Sandwich Cookies
# 1                                         All-Seasons Salt
# 2                     Robust Golden Unsweetened Oolong Tea
# 3        Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4                                Green Chile Anytime Sauce
#                                ...
# 49689                        HIGH PERFORMANCE ENERGY DRINK
# 49690                        ORIGINAL PANCAKE & WAFFLE MIX
# 49691      ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692                               SPRING WATER BODY WASH
# 49693                              BURRITO- STEAK & CHEESE
# Name: product_name, Length: 49694, dtype: object

# %%
products_df['product_name'] = products_df['product_name'].str.lower()
products_df = products_df.drop_duplicates(subset=['product_name'], keep='first')

# %%
products_df['product_name'].dropna().str.lower().duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please try to use `isna` method here to take product names that are not missing. Then apply `str.lower()` and find duplicates.
#
#
#
# Do not forget about the conclusion please. What can you say about these duplicates?
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# I see the updates, well done!
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
#Check for duplicate rows
departments_df.duplicated().sum()
# Out:
# 0

# %%
departments_df.isna().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
departments_df
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
departments_df['department_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# There do not appear to be any duplicates in department_id

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Are there any duplicates in `department_id`?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Good!
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment 2 ⚠️</h2>
#
# It is enough to print their quantity.
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
#Check for duplicate rows
duplicated_deps = aisles_df[aisles_df.duplicated(keep=False)]
print(duplicated_deps)
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# There do not appear to be any duplicated rows

# %%
aisles_df['aisle_id'].duplicated().sum()
#departments_df['department_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# There do not appear to be any duplicates in aisle_id

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Are there any duplicates in `aisle_id`?
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# What about the `aisle_id` column?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 3 ✔️</h2>
#
#
# Good.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for fully duplicate rows
duplicated_prods = order_products_df[order_products_df.duplicated(keep=False)]
print(duplicated_prods)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Double check for any other tricky duplicates
order_products_df.duplicated(subset= ['order_id','product_id']).sum()
# Out:
# 0

# %% [markdown]
# Checking to see if any duplicates share order_id & product_id #s

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment  ✔️</h2>
#
# Well done! You can also take two columns and then apply the `duplicated` method.
# </div>

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %%
# Are all of the missing product names associated with aisle ID 100?
products_df[products_df['product_name'].isnull()]['aisle_id'].unique()

    #print(duplicated_products['aisle_id'].value_counts())
# Out:
# array([100])

# %%
products_df.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %% [raw]
# Yes. All null values are associated with aisle ID 100 as it is the only value present for aisle_id across missing product names

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
#
# > Yes
#
# How do you know that **all** of the missing product names associated with aisle ID 100?
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Would you elaborate on this?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment 3 ✔️</h2>
#
#
# Good!
#
# </div>

# %%
# Are all of the missing product names associated with department ID 21?

products_df[products_df['product_name'].isnull()]['department_id'].value_counts()


#print(duplicated_products['department_id'].value_counts())
# Out:
# 21    1
# Name: department_id, dtype: int64

# %% [markdown]
# Yes. Using the same function as above, we can see that for missing values, dept id 21 is the only game in town

# %%
# What is this ailse and department?
aisle_100 = aisles_df[aisles_df['aisle_id'] == 100]
display(aisle_100)

dept_21 = departments_df[departments_df['department_id'] == 21]
display(dept_21)
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# - Aisle 100 = 'missing'
# - dept_id 21 = 'missing'

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please try to print department from `departments` dataframe where department_id is 21.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Yes, each missing product name has `'missing'` label.
# </div>

# %%
# Fill missing product names with 'Unknown'
products_df['product_name'] = products_df['product_name'].fillna('Unknown')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Yes, we should replace them with some unique value, as it's hard to figure out a safer replacement.
# </div>

# %% [markdown]
# ### `orders` data frame

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ⚠️</h2>
#
# It will be great if you try to find missing values here and further.
#
# </div>

# %%
# Are there any missing values where it's not a customer's first order?
orders_df[orders_df['days_since_prior_order'].isnull() & (orders_df['order_number'] > 1)]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# No. We receive a blank set in Output

# %% [markdown]
# ### `order_products` data frame

# %%
# What are the min and max values in this column?
order_products_df['add_to_cart_order'].min(), order_products_df['add_to_cart_order'].max()
# Out:
# (1.0, 64.0)

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
add_to_cart_order = order_products_df[order_products_df['add_to_cart_order'].isna()]['order_id'].unique()
add_to_cart_order
# Out:
# array([2449164, 1968313, 2926893, 1717990, 1959075,  844733,   61355,
#         936852,  264710, 1564093,  129627,  293169, 2849370, 1386261,
#        3308010,  903110, 2136777, 3347453, 1888628,  165801, 2094761,
#        1038146, 2997021,  813364, 2256933,  171934, 2409109, 1730767,
#        1169835,  733526,  404157, 3125735,  747668, 1800005, 1961723,
#         871281,  388234, 1648217, 1477139,  102236, 1021563, 1832957,
#        2721963,  678116, 1220886, 1673227, 2999801, 1633337, 2470674,
#        2625444, 1677118, 2479011, 3383594, 1183255, 1713430, 2652650,
#        1598369, 1916118,  854647, 1302315,  888470,  180546, 2621907,
#        1308785, 2729254,    9310, 2170451, 2979697, 1625713, 1529171])

# %%
# Do all orders with missing values have more than 64 products?

missing_orders_df = order_products_df[order_products_df['order_id'].isin(add_to_cart_order)].groupby('order_id')['product_id'].count().min()

print(missing_orders_df)
# Out:
# 65

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ⚠️</h2>
#
# try to write code so that one does not need to scroll the cell :)
# </div>

# %% [markdown]
# Minimum order quantity for order with missing values = 65, therefore all orders with missing values have more than 64 products

# %%
# Replace missing values with 999 and convert column to integer type
order_products_df['add_to_cart_order'] = order_products_df['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# ### Conclusion
# - There were 1361 missing values for product_name in products_df that we filled in with 'Unknown'.
# - There were 28,819 missing values from the days_since_prior_order dataframe that we replaced with the integer 999.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Great! Now we are ready for the exploratory data analysis.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please add a conclusion about the whole data preprocessing part here.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Well done! </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
orders_df['order_hour_of_day'].min(), orders_df['order_hour_of_day'].max()
# Out:
# (0, 23)

# %%
orders_df['order_hour_of_day'].value_counts().sort_index()
# Out:
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64

# %%
orders_df['order_dow'].min(), orders_df['order_dow'].max()
# Out:
# (0, 6)

# %%
orders_df['order_dow'].value_counts().sort_index()
# Out:
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_dow, dtype: int64

# %% [markdown]
# - order_hour_of_day ranges from 0-23
# - order_dow ranges from 0-6
# - all figures from 0-23 and 0-6 are represented in hour_of_day & dow respectively

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Correct.
# </div>

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(orders_df['order_hour_of_day'], bins=24, edgecolor='black')
plt.title('Distribution of Orders by Hour of Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Orders')
plt.xticks(range(0, 24))  # Set ticks for each hour
plt.grid(axis='y')

plt.show()

# %% [markdown]
# People tend to shop between 10-4, and this represents the daily peak of sales.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# It's great that you add a title and both axes labels 👍 So most orders occur between 9 AM and 5 PM.
#
#
# </div>

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(orders_df['order_dow'], bins=7, edgecolor='black')
plt.title('Distribution of Orders by Days of the Week')
day_labels = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
plt.xlabel('Day of the Week')
plt.ylabel('Number of Orders')
plt.xticks(range(0, 7), day_labels)  
plt.grid(axis='y')


plt.show()

# %% [markdown]
# Customers place orders throughout the week. Orders are greatest on Sundays and Mondays before plateauing for the rest of the week.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Good.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
# Since we have less than 20-30 values, a simple bar chart would be a better choice.
#
# </div>

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
orders_df['days_since_prior_order'].value_counts().sort_index().plot.bar(figsize = (10, 6))
plt.xlabel('Days Since Prior Order')
plt.ylabel('Number of Orders')
plt.title('Number of Orders Since Prior Order')
plt.show()

print(orders_df['days_since_prior_order'].mean())
# Out:
# 11.101813900274362

# %% [markdown]
# Customers wait anywhere from 0-30 days before placing a reorder. 30 days is the mode, and 7 days is the next most popular wait time, suggesting that customers using Instacart primarily use it on either a weekly or monthly basis.  Customers wait a median of 11 days before reordering, marking the midpoint of days since last order

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Does mean tell us much? Let's add a chart here :) Please do not forget to add a title and both axes labels on each chart :)
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Good. Some people may make an order once a month.
# </div>

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
orders_df[orders_df['order_dow'] == 3]['order_hour_of_day'].plot(kind='hist', bins=24)
# Include an alpha value so we can fully see both histograms
orders_df[orders_df['order_dow'] == 6]['order_hour_of_day'].plot(kind='hist', bins=24, alpha=0.8)

plt.title('Wed vs Sat Order Distributions')
plt.legend(['Wednesday', 'Saturday'])
plt.xlabel('Time of Day')
plt.ylabel('Number of Orders')

xticks = range(0, 24, 3)  # for example, set ticks at every 3 hours
xticklabels = ['12 AM', '3 AM', '6 AM', '9 AM', '12 PM', '3 PM', '6 PM', '9 PM']  # Custom labels for hours
plt.xticks(ticks=xticks)
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Very good.
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Although the histogram is a useful chart to compare the distributions, we have to either use a bar chart for the categorical data or keep an eye on **bins** parameter. Since we have 24 hours, try to use 24 bins.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Correct! </div>

# %% [markdown]
# The distributions for both days is almost identical. Sales are neglible until 7am, experiencing another boost during lunch rush from 11-1 before tapering off for the rest of the day. Orders are slightly higher on Saturdays from 11-5 vs Wednesdays

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
orders_df.groupby('user_id')['order_number'].count().plot(kind='hist',bins=25, title = 'Distribution of Number of Orders per Customer')
                                                         
plt.xlabel('Number of Items in Order')
plt.ylabel('Number of Users Placing Order')
#plt.title("Distribution of Number of Orders per Customer")
plt.show()

# %% [markdown]
# Most customer orders are under 5 items, with the vast majority under 10 items. The most popular order size consists of 1 item, falling off exponentially for each item added and falling nearly flat beyond 15 items

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please add a conclusion and a title with labels :)
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Looks great! </div>

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
merged = pd.merge(order_products_df, products_df, on='product_id')

product_order_counts = merged.groupby(['product_id', 'product_name']).size()

print(product_order_counts.sort_values(ascending=False).head(20))
# Out:
# product_id  product_name
# 24852       banana                      66050
# 13176       bag of organic bananas      53297
# 21137       organic strawberries        37039
# 21903       organic baby spinach        33971
# 47209       organic hass avocado        29773
# 47766       organic avocado             24689
# 47626       large lemon                 21495
# 16797       strawberries                20018
# 26209       limes                       19690
# 27845       organic whole milk          19600
# 27966       organic raspberries         19197
# 22935       organic yellow onion        15898
# 24964       organic garlic              15292
# 45007       organic zucchini            14584
# 39275       organic blueberries         13879
# 49683       cucumber kirby              13675
# 28204       organic fuji apple          12544
# 5876        organic lemon               12232
# 8277        apple honeycrisp organic    11993
# 40706       organic grape tomatoes      11781
# ...

# %% [markdown]
# Banans, strawberries, Spinach & Avocados make up the top 6 most ordered items. The remainder of the top orders are primarily other fruits & veggies.
# Produce (department_id 4) is the revenue engine, with aisles: [24, 123 and 83] containing 19 of the 20 most ordered items!

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Interesting :)
# </div>

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
import matplotlib.pyplot as plt
items_per_order = order_products_df.groupby('order_id')['product_id'].count()
print("Median number of items in an order:", items_per_order.median().astype(int))
plt.hist(items_per_order, bins=125, edgecolor='black')
plt.title('Distribution of Number of Items per Order')
plt.xlabel('Number of Items in Order')
plt.xlim(0, 50)
plt.ylabel('Frequency')
plt.show()
# Out:
# Median number of items in an order: 8

# %% [markdown]
# The most common order size is a single item. The next most common order size is 5 items, at which point order-size drops rapidly.  The majority of orders consist of fewer than 20 items,

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# So what can be said about the typical order?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Agreed.</div>

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
reordered_items = order_products_df[order_products_df['reordered'] == 1]

# %%
most_reordered = reordered_items['product_id'].value_counts().head(20)
print(most_reordered)
# Out:
# 24852    55763
# 13176    44450
# 21137    28639
# 21903    26233
# 47209    23629
# 47766    18743
# 27845    16251
# 47626    15044
# 27966    14748
# 16797    13945
# 26209    13327
# 22935    11145
# 24964    10411
# 45007    10076
# 49683     9538
# 28204     8989
# 8277      8836
# 39275     8799
# 5876      8412
# 49235     8389
# Name: product_id, dtype: int64

# %% [markdown]
# The list above are the 20 most re-ordered items. Unfortunately it is meaningless to us until we merge this with the products_df on the 'product id' column. We will name this column in most_reordered to match with orders_df

# %%
most_reordered = most_reordered.reset_index()
most_reordered.columns = ['product_id', 'count']
# display(most_reordered)
popular_reorders = most_reordered.merge(products_df, on='product_id')
print(popular_reorders)
# Out:
#     product_id  count              product_name  aisle_id  department_id
# 0        24852  55763                    banana        24              4
# 1        13176  44450    bag of organic bananas        24              4
# 2        21137  28639      organic strawberries        24              4
# 3        21903  26233      organic baby spinach       123              4
# 4        47209  23629      organic hass avocado        24              4
# 5        47766  18743           organic avocado        24              4
# 6        27845  16251        organic whole milk        84             16
# 7        47626  15044               large lemon        24              4
# 8        27966  14748       organic raspberries       123              4
# 9        16797  13945              strawberries        24              4
# 10       26209  13327                     limes        24              4
# 11       22935  11145      organic yellow onion        83              4
# ...

# %% [markdown]
# The produce department dominates this list, containing 18 of the 20 most reordered items. In particular: bananas, strawberries, spinach & avocadoes have been flying off the shelves!

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Would you please display their names as well?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Correct! </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
# </div>

# %% [markdown]
# ## Conclusion
#
# Produce is by far the key revenue driver for Instacart. Customer traffic is fairly consistent throughout the week, with time of day having a greater effect on order volume. As noted previously, most orders occur between 9am and 5pm. Instacart shoppers tend to diverge into one of two groups: weekly or monthly shoppers. The majority of orders are for fewer than 10 items, with a single item being the most popular order size.
# Finally, Instacart customers absolutely love their bananas, as evidenced by the fact that bananas make up the top top 2 spots in our list of most ordered items. Bananas (organic and not) are more than twice as popular as the next most sold item, strawberries (both organic and not).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Excellent job, thank you so much!
# </div>
